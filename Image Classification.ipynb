# %%
from PIL import Image
import numpy as np
from sklearn import cluster
import matplotlib.pyplot as plt

# %%
def open_image_and_convert_it_to_numpy_array():
  im=np.array(Image.open(r'C:\Users\jbsan\OneDrive\Desktop\Cat.jpeg'))
  print('Image size: ',im.shape)
  height=im.shape[0]
  width=im.shape[1]
  band_n=im.shape[2]
  numpy_arr=im.reshape(-1,band_n)
  return height,width, numpy_arr

# %%
height, width, X = open_image_and_convert_it_to_numpy_array()
# Out:
# Image size:  (183, 275, 3)

# %%
print('Image has been converted to numpy array')
print('---------------')
print('Red|Green|Blue')
print('---------------')
print(X)
print('---------------')
# Out:
# Image has been converted to numpy array
# ---------------
# Red|Green|Blue
# ---------------
# [[255 255 255]
#  [255 255 255]
#  [255 255 255]
#  ...
#  [241 241 241]
#  [241 241 241]
#  [240 240 240]]
# ---------------

# %%
class_n=7
k_means= cluster.KMeans(class_n)
k_means.fit(X)
# Out:
# KMeans(n_clusters=7)

# %%
X_classified=k_means.labels_
result=X_classified.reshape(height, width)

# %%
plt.figure(figsize=(12,12))
cmap=plt.get_cmap('jet', np.max(result) - np.min(result) +1)

# %%
plt.subplot(211)
plt.imshow(X.reshape(height, width, 3))

# %%
plt.subplot(212)
plt.imshow(result, cmap=cmap)

# %%
cax= plt.axes([0.75,0.125,0.025,0.34])
plt.colorbar(cax=cax)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[14], line 2
#       1 cax= plt.axes([0.75,0.125,0.025,0.34])
# ----> 2 plt.colorbar(cax=cax)
#       3 plt.show()
#
# File c:\Users\jbsan\AppData\Local\Programs\Python\Python312\Lib\site-packages\matplotlib\pyplot.py:2337, in colorbar(mappable, cax, ax, **kwargs)
#    2335     mappable = gci()
#    2336     if mappable is None:
# -> 2337         raise RuntimeError('No mappable was found to use for colorbar '
#    2338                            'creation. First define a mappable such as '
#    2339                            'an image (with imshow) or a contour set ('
#    2340                            'with contourf).')
#    2341 ret = gcf().colorbar(mappable, cax=cax, ax=ax, **kwargs)
#    2342 return ret
#
# RuntimeError: No mappable was found to use for colorbar creation. First define a mappable such as an image (with imshow) or a contour set (with contourf).
