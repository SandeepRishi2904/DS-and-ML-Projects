# %%
import pandas as pd
import matplotlib.pylab as plt
inc=pd.read_csv('income.csv')
inc.head()
# Out:
#       Name  Age  Income($)
# 0      Rob   27      70000
# 1  Michael   29      90000
# 2    Mohan   29      61000
# 3   Ismail   28      60000
# 4     Kory   42     150000

# %%
plt.scatter(inc.Age,inc['Income($)'])

# %%
incdt=inc.loc[:,['Age','Income($)']]
incdt.head()
# Out:
#    Age  Income($)
# 0   27      70000
# 1   29      90000
# 2   29      61000
# 3   28      60000
# 4   42     150000

# %%
import scipy.cluster.hierarchy as sch
plt.figure(figsize=(10,7))
dnd=sch.dendrogram(sch.linkage(incdt,method='ward'))
plt.title('dendrogram')
plt.xlabel('year')
plt.ylabel('euclidean distance')
# Out:
# Text(0, 0.5, 'euclidean distance')

# %%
x=incdt.values
x
# Out:
# array([[    27,  70000],
#        [    29,  90000],
#        [    29,  61000],
#        [    28,  60000],
#        [    42, 150000],
#        [    39, 155000],
#        [    41, 160000],
#        [    38, 162000],
#        [    36, 156000],
#        [    35, 130000],
#        [    37, 137000],
#        [    26,  45000],
#        [    27,  48000],
#        [    28,  51000],
#        [    29,  49500],
#        [    32,  53000],
#        [    40,  65000],
#        [    41,  63000],
#        [    43,  64000],
#        [    39,  80000],
#        [    41,  82000],
#        [    39,  58000]], dtype=int64)
